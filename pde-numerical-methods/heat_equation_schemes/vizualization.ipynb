# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
data_exp = np.loadtxt('result_explicit.txt')
N_arr_exp = data_exp[:,0]
M_arr_exp = data_exp[:,1]
errors_exp= data_exp[:,2]
rate_exp=[]

for i in range(0,len(N_arr_exp)-1):
    h1 = 1.0/(M_arr_exp[i+1]-0.5)
    h0 = 1.0/(M_arr_exp[i]-0.5)
    rate_exp.append(np.log(errors_exp[i+1]/errors_exp[i])/np.log(M_arr_exp[i]/M_arr_exp[i+1]))
data_imp = np.loadtxt('result_implicit.txt')
N_arr_imp = data_imp[:,0]
M_arr_imp = data_imp[:,1]
errors_imp= data_imp[:,2]
rate_imp=[]

for i in range(0,len(N_arr_imp)-1):
    h1 = 1.0/(M_arr_imp[i+1]-0.5)
    h0 = 1.0/(M_arr_imp[i]-0.5)
    rate_imp.append(np.log(errors_imp[i+1]/errors_imp[i])/np.log(h1/h0))

print(rate_exp)
print()
print(rate_imp)
# Out:
# [2.0750765189938503, 2.0420173304956553, 2.022018343787103, 2.0112489648311374, 2.005681650562841]
#
# [2.003957006759615, 2.000865318706207, 2.0001707683716066, 2.0000232960112694, 1.9999995881534622]

# %% [markdown]
# # Порядки сходимости для явной схемы

# %%
for i in range(0,len(M_arr_exp)-1):
    print(f"Порядок сходимости для (M1,M2)=({int(M_arr_exp[i])},{int(M_arr_exp[i+1])}) есть {rate_exp[i]}")
# Out:
# Порядок сходимости для (M1,M2)=(10,20) есть 2.0750765189938503
# Порядок сходимости для (M1,M2)=(20,40) есть 2.0420173304956553
# Порядок сходимости для (M1,M2)=(40,80) есть 2.022018343787103
# Порядок сходимости для (M1,M2)=(80,160) есть 2.0112489648311374
# Порядок сходимости для (M1,M2)=(160,320) есть 2.005681650562841

# %% [markdown]
# # Порядки сходимости для неявной схемы

# %%
for i in range(0,len(M_arr_imp)-1):
    print(f"Порядок сходимости для (M1,M2)=({int(M_arr_imp[i])},{int(M_arr_imp[i+1])}) есть {rate_imp[i]}")
# Out:
# Порядок сходимости для (M1,M2)=(10,20) есть 2.003957006759615
# Порядок сходимости для (M1,M2)=(20,40) есть 2.000865318706207
# Порядок сходимости для (M1,M2)=(40,80) есть 2.0001707683716066
# Порядок сходимости для (M1,M2)=(80,160) есть 2.0000232960112694
# Порядок сходимости для (M1,M2)=(160,320) есть 1.9999995881534622

# %%
fig = make_subplots(rows=2,cols=1,subplot_titles=("Явная схема","Неявная схема"))
fig.add_trace(go.Scatter(x=N_arr_exp,y=errors_exp,mode='lines+markers',name='Явная схема'),row=1,col=1)
fig.add_trace(go.Scatter(x=N_arr_imp,y=errors_imp,mode='lines+markers',name='Неявная схема'),row=2,col=1)

fig.update_xaxes(title_text='N')
fig.update_yaxes(title_text='Error')
fig.update_layout(title_text='График зависимости ошибки реального и численного решения от N')
fig.show()

# %% [markdown]
# ## ПРОВЕРКА БЕЗУСЛОВНОЙ УСТОЙЧИВОСТИ N=M

# %%
data_imp = np.loadtxt('result_implicit.txt')
N_arr_imp = data_imp[:,0]
M_arr_imp = data_imp[:,1]
errors_imp= data_imp[:,2]
rate_imp=[]

for i in range(0,len(N_arr_imp)-1):
    h1 = 1.0/(M_arr_imp[i+1]-0.5)
    h0 = 1.0/(M_arr_imp[i]-0.5)
    rate_imp.append(np.log(errors_imp[i+1]/errors_imp[i])/np.log(h1/h0))


print(rate_imp)
# Out:
# [1.9749868774819745, 1.9888340509985103, 2.002600963878842, 2.035221098713151, 2.160988565927791]

# %%
for i in range(0,len(M_arr_imp)-1):
    print(f"Порядок сходимости для (M1,M2)=({int(M_arr_imp[i])},{int(M_arr_imp[i+1])}) есть {rate_imp[i]}")
# Out:
# Порядок сходимости для (M1,M2)=(10,20) есть 1.9749868774819745
# Порядок сходимости для (M1,M2)=(20,40) есть 1.9888340509985103
# Порядок сходимости для (M1,M2)=(40,80) есть 2.002600963878842
# Порядок сходимости для (M1,M2)=(80,160) есть 2.035221098713151
# Порядок сходимости для (M1,M2)=(160,320) есть 2.160988565927791

# %%
fig2 = go.Figure()
fig2.add_trace(go.Scatter(x=N_arr_imp,y=errors_imp,mode='lines+markers',name='Неявная схема'))

fig2.update_xaxes(title_text='N')
fig2.update_yaxes(title_text='Error')
fig2.update_layout(title_text='График зависимости ошибки реального и численного решения от N,случай N=M')
fig2.show()
